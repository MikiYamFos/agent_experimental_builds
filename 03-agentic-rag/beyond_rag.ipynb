# %%
from gitsource import GithubRepositoryDataReader
from minsearch import AppendableIndex, Highlighter, Tokenizer
from minsearch.tokenizer import DEFAULT_ENGLISH_STOP_WORDS

reader = GithubRepositoryDataReader(
    repo_owner="evidentlyai",
    repo_name="docs",
    allowed_extensions={"md", "mdx"},
)
files = reader.read()

parsed_docs = [doc.parse() for doc in files]

index = AppendableIndex(
    text_fields=["title", "description", "content"], keyword_fields=["filename"]
)
index.fit(parsed_docs)

# %% [markdown]
# highlight_fields: Which fields to extract snippets from
#
# max_matches: How many snippets to show per document (3 = not too many)
#
# snippet_size: How long each snippet should be (50 tokens = enough to understand relevance)
#
# stop_words: Words to ignore (like "evidently" which appears everywhere)
#
# stemmer: Matches word variations (use → using, etc.)

# %%
query = "how do I use evidently to monitor my machine learning models?"

search_results = index.search(query)

stopwords = DEFAULT_ENGLISH_STOP_WORDS | {"evidently"}

highlighter = Highlighter(
    highlight_fields=["content"],
    max_matches=3,
    snippet_size=50,
    tokenizer=Tokenizer(stemmer="snowball", stop_words=stopwords),
)

highlighter.highlight(query, search_results)
# Out:
# [{'title': 'Use HuggingFace models',
#   'description': 'How to use models from HuggingFace as evaluators.',
#   'content': {'matches': ['...downloading and using ML **models** from HuggingFace. This l...',
#     '...criteria from the source **model**, e.g. classify texts by ...',
#     '.... There are:\n\n* Ready-to-**use** descriptors that wrap a ...'],
#    'total_matches': 33},
#   'filename': 'metrics/customize_hf_descriptor.mdx'},
#  {'title': 'What is Evidently?',
#   'description': 'Welcome to the Evidently documentation.',
#   'mode': 'wide',
#   'content': {'matches': ['...elps evaluate, test, and **monitor** data and AI-powered syst...',
#     '...ucts: from predictive ML **models** to complex LLM-powered s...',
#     '.../Card>\n  <Card title="ML **monitoring**" icon="table" href="/qui...'],
#    'total_matches': 4},
#   'filename': 'introduction.mdx'},
#  {'title': 'Why Evidently?',
#   'description': 'Why choose Evidently.',
#   'content': {'matches': ['...ucts: whether it’s an ML **model**, an LLM app, or a comple...',
#     '...workflow.\n\nOur tools are **model**-, framework-, and applic...',
#     '.... It’s up to you.\xa0\n- Add **monitoring** as you are ready to move...'],
#    'total_matches': 6},
#   'filename': 'faq/why_evidently.mdx'},
#  {'title': 'Evidently Cloud',
#   'description': 'How to set up Evidently Cloud account.',
#   'icon': 'cloud',
#   'content': {'matches': ['... and Evidently Cloud v1, **use** `from evidently.ui.works...'],
#    'total_matches': 1},
#   'filename': 'docs/setup/cloud.mdx'},
#  {'title': 'Evidently Cloud v2',
#   'description': 'A new version of Evidently Cloud available starting April 10, 2025.',
#   'content': {'matches': ['...        |\n\nMake sure you **use** the matching version of ...'],
#    'total_matches': 1},
#   'filename': 'faq/cloud_v2.mdx'},
#  {'title': 'Telemetry',
#   'description': 'What data is collected when you use Evidently open-source.',
#   'content': {'matches': ['...llect telemetry when you **use** **Evidently **Monitoring** U...',
#     '...when you **use** **Evidently **Monitoring** UI**. We DO NOT collect ...',
#     '...t any telemetry when you **use** the tool as a library, f...'],
#    'total_matches': 7},
#   'filename': 'faq/telemetry.mdx'},
#  {'title': 'No code evals',
#   'description': 'How to evaluate your data in a no-code interface.',
#   'content': {'matches': ['... when you upload it.\n- ****Use** an existing Dataset**. S...',
#     '...  **What are Datasets?** **Learn** how to manage and upload...',
#     '...u section if you plan to **use** an LLM for evaluations. ...'],
#    'total_matches': 14},
#   'filename': 'docs/platform/evals_no_code.mdx'},
#  {'title': 'Self-hosting',
#   'description': 'How to self-host the open-source Evidently UI service.',
#   'icon': 'window-restore',
#   'content': {'matches': ['... the UI Service to get a **monitoring** Dashboard and organize t...',
#     '...he snapshots and run the **monitoring** UI on the same **machine**.\n...',
#     '...onitoring UI on the same **machine**.\n\nImports:\n\n```python\nfr...'],
#    'total_matches': 7},
#   'filename': 'docs/setup/self-hosting.mdx'},
#  {'title': 'LLM as a judge',
#   'description': 'How to create and evaluate an LLM judge.',
#   'content': {'matches': ["...e'll explore two ways to **use** an LLM as a judge:\n\n- **...",
#     '....\n- An OpenAI API key to **use** for the LLM evaluator.\n\n...',
#     '... "ground truth". You can **use** it to evaluate the quali...'],
#    'total_matches': 15},
#   'filename': 'examples/LLM_judge.mdx'},
#  {'title': 'Evidently and GitHub actions',
#   'description': 'Testing LLM outputs as part of the CI/CD flow.',
#   'content': {'matches': ['You can **use** Evidently together with ...',
#     '...an safely tweak prompts, **models**, or logic without breaki...'],
#    'total_matches': 2},
#   'filename': 'examples/GitHub_actions.mdx'}]

# %%
file_index = {doc["filename"]: doc["content"] for doc in parsed_docs}

file_index["docs/setup/self-hosting.mdx"]
# Out:
# '<Info>\n  This page explains how to self-host the lightweight open-source platform. [Contact us](https://www.evidentlyai.com/get-demo) for Enterprise version with extra features and support. Compare [OSS vs. Enterprise/Cloud](/faq/oss_vs_cloud).\n</Info>\n\nIn addition to using Evidently Python library, you can self-host the UI Service to get a monitoring Dashboard and organize the results of your evaluations. This is optional: you can also view evaluation results in Python or export to JSON or HTML.\n\nTo get a self-hostable Dashboard, you must:\n\n- Create a Workspace (local or remote) to store your data.\n- Launch the UI service.\n\n## 1. Create a Workspace\n\n<Tip>\n  Sign up for a free [Evidently Cloud](cloud) account to get a managed version instantly.\n</Tip>\n\nOnce you [install Evidently](/docs/setup/installation), you will need to create a `workspace`. This designates a remote or local directory where you will store the evaluation results (JSON Reports called `snapshots`), traces or datasets. The UI Service will read the data from this source.\n\nAs a storage backend, Evidently supports:\n\n- a file system\n- any SQL-like database (such as SQLite or Postgres)\n- any S3-compatible storage (such as Amazon S3, GCS, or MinIO – through `fsspec`).\n\nThere are three scenarios, based on where you run the UI Service and store data.\n\n- **Local Workspace**. Both the UI Service and data storage are local.\n- **Remote Workspace**. Both the UI Service and data storage are remote.\n- **Workspace with remote data storage**. Run the UI Service and store data on different servers.\n\n### Local Workspace\n\nHere, you generate, store the snapshots and run the monitoring UI on the same machine.\n\nImports:\n\n```python\nfrom evidently.ui.workspace import Workspace\nfrom evidently.ui.workspace import WorkspaceBase\n```\n\nTo create a local Workspace and assign a name:\n\n```python\nws = Workspace.create("evidently_ui_workspace")\n```\n\nYou can pass a `path` parameter to specify the path to a local directory.\n\n### Remote Workspace\n\n<Info>\n  **Code example (Docker)**. See the [remote service example](https://github.com/evidentlyai/evidently/tree/main/examples/service).\n</Info>\n\nIn this scenario, you send the snapshots to a remote server. You must run the Monitoring UI on the same remote server. It will directly interface with the filesystem where the snapshots are stored.\n\nImports:\n\n```python\nfrom evidently.ui.remote import RemoteWorkspace\nfrom evidently.ui.workspace import Workspace\nfrom evidently.ui.workspace import WorkspaceBase\n```\n\nTo create a remote Workspace (UI should be running at this address):\n\n```python\nworkspace = RemoteWorkspace("http://localhost:8000")\n```\n\nYou can pass the following parameters:\n\n| Parameter                  | Description                                                                                  |\n| -------------------------- | -------------------------------------------------------------------------------------------- |\n| `self.base_url = base_url` | URL for the remote UI service.                                                               |\n| `self.secret = secret`     | String with secret, None by default. Use it if access to the URL is protected by a password. |\n\n### Remote snapshot storage\n\nIn the examples above, you store the snapshots and run the UI on the same server. Alternatively, you can store snapshots in a remote data store (such as an S3 bucket). The Monitoring UI service will interface with the designated data store to read the snapshot data.\n\nTo connect to data stores Evidently uses `fsspec` that allows accessing data on remote file systems via a standard Python interface.\n\nYou can verify supported data stores in the Fsspec documentation ([built-in implementations](https://filesystem-spec.readthedocs.io/en/latest/api.html#built-in-implementations) and [other implementations](https://filesystem-spec.readthedocs.io/en/latest/api.html#other-known- ...

# %%
from typing import Any, Dict, List


class SearchTools:
    """
    Provides search and file retrieval utilities over an indexed data store.
    """

    def __init__(
        self, index: Any, highlighter: Any, file_index: Dict[str, str]
    ) -> None:
        """
        Initialize the SearchTools instance.
        Args:
            index: Searchable index providing a `search` method.
            highlighter: Highlighter used to annotate search results.
            file_index (Dict[str, str]): Mapping of filenames to file contents.
        """
        self.index = index
        self.highlighter = highlighter
        self.file_index = file_index

    def search(self, query: str) -> List[Dict[str, Any]]:
        """
        Search the index for results matching a query and highlight them.
        Args:
            query (str): The search query to look up in the index.
        Returns:
            List[Dict[str, Any]]: A list of highlighted search result objects.
        """
        search_results = self.index.search(query=query, num_results=5)
        return self.highlighter.highlight(query, search_results)

    def get_file(self, filename: str) -> str:
        """
        Retrieve a file's contents by filename.
        Args:
            filename (str): The filename of the file to retrieve.
        Returns:
            str: The file contents if found, otherwise an error message.
        """
        if filename in self.file_index:
            return self.file_index[filename]
        return f"file {filename} does not exist"

# %%
search_tools = SearchTools(index, highlighter, file_index)

# %%
instructions = """
You're a documentation assistant.

Answer the user question using only the documentation knowledge base.

Make 3 iterations:

1) First iteration:
   - Perform one search using the search tool to identify potentially relevant documents.
   - Explain (in 2â€“3 sentences) why this search query is appropriate for the user question.

2) Second iteration:
   - Analyze the results from the previous search.
   - Based on the filenames or documents returned, perform:
       - Up to 2 additional search queries to refine or expand coverage, and
       - One or more get_file calls to retrieve the full content of the most relevant documents.
   - For each search or get_file call, explain (in 2â€“3 sentences) why this action is necessary and how it helps answer the question.

3) Third iteration:
   - Analyze the retrieved document contents from get_file.
   - Synthesize the information from these documents into a final answer to the user.

IMPORTANT:
- At every step, explicitly explain your reasoning for each search query or file retrieval.
- Use only facts found in the documentation knowledge base.
- Do not introduce outside knowledge or assumptions.
- If the answer cannot be found in the retrieved documents, clearly inform the user.

Additional notes:
- The knowledge base is entirely about Evidently, so you do not need to include the word "evidently" in search queries.
- Prefer retrieving and analyzing full documents (via get_file) before producing the final answer.
"""

# %%
from toyaikit.tools import Tools

agent_tools = Tools()
agent_tools.add_tools(search_tools)

agent_tools.get_tools()
# Out:
# [{'type': 'function',
#   'name': 'get_file',
#   'description': "Retrieve a file's contents by filename.\nArgs:\n    filename (str): The filename of the file to retrieve.\nReturns:\n    str: The file contents if found, otherwise an error message.",
#   'parameters': {'type': 'object',
#    'properties': {'filename': {'type': 'string',
#      'description': 'filename parameter'}},
#    'required': ['filename'],
#    'additionalProperties': False}},
#  {'type': 'function',
#   'name': 'search',
#   'description': 'Search the index for results matching a query and highlight them.\nArgs:\n    query (str): The search query to look up in the index.\nReturns:\n    List[Dict[str, Any]]: A list of highlighted search result objects.',
#   'parameters': {'type': 'object',
#    'properties': {'query': {'type': 'string',
#      'description': 'query parameter'}},
#    'required': ['query'],
#    'additionalProperties': False}}]

# %%
from openai import OpenAI
from toyaikit.llm import OpenAIClient
from toyaikit.chat.runners import OpenAIResponsesRunner
from toyaikit.chat.interface import IPythonChatInterface
from toyaikit.chat.runners import DisplayingRunnerCallback

llm_client = OpenAIClient(model="gpt-4o-mini", client=OpenAI())

chat_interface = IPythonChatInterface()
runner_callback = DisplayingRunnerCallback(chat_interface=chat_interface)

# %%
agent = OpenAIResponsesRunner(
    tools=agent_tools,
    developer_prompt=instructions,
    chat_interface=chat_interface,
    llm_client=llm_client,
)

# %%
result = agent.loop(query + " show me the code", callback=runner_callback)
# Out:
# -> Response received
#             <details>
#             <summary>Function call: <tt>search({"query":"monitor machine learning models code"})</tt></summary>
#             <div>
#                 <b>Call</b>
#                 <pre>{"query":"monitor machine learning models code"}</pre>
#             </div>
#             <div>
#                 <b>Output</b>
#                 <pre>[
#   {
#     "title": "No code evals",
#     "description": "How to evaluate your data in a no-code interface.",
#     "content": {
#       "matches": [
#         "...  **What are Datasets?** **Learn** how to manage and upload...",
#         "... following methods:\n\n- ****Model**-based**: use built-in **machine**...",
#         "...el-based**: use built-in **machine** **learning** **models**, like se..."
#       ],
#       "total_matches": 7
#     },
#     "filename": "docs/platform/evals_no_code.mdx"
#   },
#   {
#     "title": "Use HuggingFace models",
#     "description": "How to use models from HuggingFace as evaluators.",
#     "content": {
#       "matches": [
#         "...downloading and using ML **models** from HuggingFace. This l...",
#         "...criteria from the source **model**, e.g. classify texts by ...",
#         "...ors that wrap a specific **model**,\n\n* A general interface ..."
#       ],
#       "total_matches": 26
#     },
#     "filename": "metrics/customize_hf_descriptor.mdx"
#   },
#   {
#     "title": "Tutorials and guides",
#     "description": "End-to-end code examples.",
#     "content": {
#       "matches": [
#         "...LLM evaluation methods. [**CODE** \\+ VIDEO]\n  &lt;/Card&gt;\n  &lt;C...",
#         "... optimization (2)\" icon=\"**code**\" href=\"https://github.co...",
#         "...e=\"GitHub actions\" icon=\"**code**\" href=\"/examples/GitHub_..."
#       ],
#       "total_matches": 13
#     },
#     "filename": "examples/introduction.mdx"
#   },
#   {
#     "title": "Synthetic data generation",
#     "description": "[NEW] Code-first synthetic data generation.",
#     "content": {
#       "matches": [
#         "...thetic data generation: [**code** example](https://github...."
#       ],
#       "total_matches": 1
#     },
#     "filename": "docs/library/synthetic_data_api.mdx"
#   },
#   {
#     "title": "All Descriptors",
#     "description": "Reference page for all row-level text and LLM evals.",
#     "content": {
#       "matches": [
#         "...rt_llm). For a reference **code** example, see this [Descr...",
#         "...ms=[\"as a large language **model**\"])`&lt;/li&gt;&lt;/ul&gt;           ...",
#         "...ructured data formats or **code** syntax.\n\n| Name         ..."
#       ],
#       "total_matches": 25
#     },
#     "filename": "metrics/all_descriptors.mdx"
#   }
# ]</pre>
#             </div>
#
#             </details>
# -> Response received
#             <div>
#                 <div><b>Assistant:</b></div>
#                 <div><p>The initial search query focused on &quot;monitor machine learning models code,&quot; which is appropriate because it aims to uncover documentation or examples related to code snippets for monitoring machine learning models. This is directly relevant to your request about using a specific platform for that purpose.</p>
# <p>The search returned several documents, including one titled &quot;Tutorials and guides,&quot; which specifies &quot;end-to-end code examples.&quot; This document could potentially contain the code you're looking for. Now, I will retrieve and analyze this document's full content to provide more precise information.</p>
# </div>
#             </div>
#             <details>
#             <summary>Function call: <tt>get_file({"filename":"examples/introduction.mdx"})</tt></summary>
#             <div>
#                 <b>Call</b>
#                 <pre>{"filename":"examples/introduction.mdx"}</pre>
#             </div>
#             <div>
#                 <b>Output</b>
#                 <pre>"&lt;Note&gt;\n  **We have an applied course on LLM evaluations\\!** Free video course with 10\\+ tutorials. [Sign up](https://www.evidentlyai.com/llm-evaluation-course-practice).\n&lt;/Note&gt;\n\n## Quickstarts\n\nIf you are new, start here.\n\n&lt;CardGroup cols={3}&gt;\n  &lt;Card title=\"LLM quickstart\" icon=\"comment-text\" href=\"/quickstart_llm\"&gt;\n    Evaluate the quality of text outputs.\n  &lt;/Card&gt;\n  &lt;Card title=\"ML quickstart\" icon=\"table\" href=\"/quickstart_ml\"&gt;\n    Test tabular data quality and data drift.\n  &lt;/Card&gt;\n  &lt;Card title=\"Tracing quickstart\" icon=\"bars-staggered\" href=\"/quickstart_tracing\"&gt;\n    Collect inputs and outputs from AI your app.\n  &lt;/Card&gt;\n&lt;/CardGroup&gt;\n\n## LLM Tutorials\n\nEnd-to-end examples of specific workflows and use cases.\n\n&lt;CardGroup cols={2}&gt;\n  &lt;Card title=\"LLM as a judge\" icon=\"scale-balanced\" href=\"/examples/LLM_judge\"&gt;\n    How to create and evaluate an LLM judge against human labels.\n  &lt;/Card&gt;\n  &lt;Card title=\"RAG evaluation\" icon=\"comment\" href=\"/examples/LLM_rag_evals\"&gt;\n    A walkthrough of different RAG evaluation metrics.\n  &lt;/Card&gt;\n  &lt;Card title=\"LLM as a jury\" icon=\"dice\" href=\"LLM_jury\"&gt;\n    Using multiple LLMs to evaluate the same output.\n  &lt;/Card&gt;\n  &lt;Card title=\"LLM evaluation methods\" icon=\"text\" href=\"LLM_evals\"&gt;\n    A walkthrough of different LLM evaluation methods. [CODE \\+ VIDEO]\n  &lt;/Card&gt;\n  &lt;Card title=\"Descriptor cookbook\" icon=\"book\" href=\"https://github.com/evidentlyai/evidently/blob/main/examples/cookbook/descriptors.ipynb\"&gt;\n    A walkthrough of different descriptors (deterministic, ML, etc.) a single notebook.\n  &lt;/Card&gt;\n  &lt;Card title=\"LLM judge prompt optimization (1)\" icon=\"hotel\" href=\"https://github.com/evidentlyai/evidently/blob/main/examples/cookbook/prompt_optimization_bookings_example.ipynb\"&gt;\n    Optimize a multi-class classifier using target labels.\n  &lt;/Card&gt;\n  &lt;Card title=\"LLM judge prompt optimization (2)\" icon=\"code\" href=\"https://github.com/evidentlyai/evidently/blob/main/examples/cookbook/prompt_optimization_code_review_example.ipynb\"&gt;\n    Optimize a binary classifier using target labels and free-form feedback.\n  &lt;/Card&gt;\n&lt;/CardGroup&gt;\n\n## ML tutorials\n\nEnd-to-end examples of specific workflows and use cases.\n\n&lt;CardGroup cols={2}&gt;\n  &lt;Card title=\"Metric cookbook\" icon=\"book\" href=\"https://github.com/evidentlyai/evidently/blob/main/examples/cookbook/metrics.ipynb\"&gt;\n    Various data/ML metrics: Regression, Classification, Data Quality, Data Drift.\n  &lt;/Card&gt;\n&lt;/CardGroup&gt;\n\n## Integrations\n\nEnd-to-end examples of integrating Evidently with other tools and platforms.\n\n&lt;CardGroup cols={2}&gt;\n  &lt;Card title=\"GitHub actions\" icon=\"code\" href=\"/examples/GitHub_actions\"&gt;\n    Running Evidently evals as part of CI/CD workflow. Native GitHub action integration for regression testing.\n  &lt;/Card&gt;\n  &lt;Card title=\"Different LLM providers as judges\" icon=\"sparkles\" href=\"https://github.com/evidentlyai/evidently/blob/main/examples/future_examples/llm_providers.ipynb\"&gt;\n    Examples of using different external evaluator LLMs as LLM judges: OpenAI, Gemini, Google Vertex, Mistral, Ollama.\n  &lt;/Card&gt;\n  &lt;Card title=\"Evidently + Grafana: LLM evals\" icon=\"chart-gantt\" href=\"https://github.com/evidentlyai/evidently/tree/main/examples/llm_eval_grafana_dashboard\"&gt;\n    Visualize Evidently LLM evaluation metrics with Grafana. (Postgres as a database).\n  &lt;/Card&gt;\n  &lt;Card title=\"Evidently+ Grafana: Data drift\" icon=\"chart-column\" href=\"https://github.com/evidentlyai/evidently/tree/main/examples/data_drift_grafana_dashboard\"&gt;\n    Visualize Evidently data drift evaluations on a Grafana dashboard. (Postgres as a database).\n  &lt;/Card&g ...
# -> Response received
#             <div>
#                 <div><b>Assistant:</b></div>
#                 <div><p>The document retrieved contains an overview of the different types of quickstarts and tutorials available for machine learning (ML) and large language models (LLMs). It includes links to specific workflows such as evaluating tabular data quality, tracing input and output of AI applications, and various LLM evaluations. This is crucial because it provides specific use cases and code examples relevant to monitoring ML models.</p>
# <p>Next, I will search for more targeted content focusing on the techniques for monitoring machine learning models and any specific code examples that may help. I will search specifically for &quot;ML quickstart&quot; and &quot;Metric cookbook.&quot; These searches will help identify whether there are specific monitoring metrics and additional tutorials available.</p>
# </div>
#             </div>
#             <details>
#             <summary>Function call: <tt>search({"query":"ML quickstart"})</tt></summary>
#             <div>
#                 <b>Call</b>
#                 <pre>{"query":"ML quickstart"}</pre>
#             </div>
#             <div>
#                 <b>Output</b>
#                 <pre>[
#   {
#     "title": "Data and ML checks",
#     "description": "Run a simple evaluation for tabular data",
#     "content": {
#       "matches": [
#         "...ions for your production **ML** systems. This includes:\n...",
#         "...ps://www.evidentlyai.com/**ml**-in-production/data-drift...",
#         "...oduction/data-drift)) in **ML** inputs and predictions i..."
#       ],
#       "total_matches": 4
#     },
#     "filename": "quickstart_ml.mdx"
#   },
#   {
#     "title": "Report",
#     "description": "How to generate Report.",
#     "content": {
#       "matches": [
#         "...ating Reports, check the **Quickstart** [for **ML**](/quickstart_ml)...",
#         "...heck the **Quickstart** [for **ML**](/quickstart_ml) or [LLM..."
#       ],
#       "total_matches": 2
#     },
#     "filename": "docs/library/report.mdx"
#   },
#   {
#     "title": "Tests",
#     "description": "How to run conditional checks.",
#     "content": {
#       "matches": [
#         "...erating Tests, \u0441heck the **Quickstart** [for **ML**](/quickstart_ml)...",
#         "...heck the **Quickstart** [for **ML**](/quickstart_ml) or [LLM..."
#       ],
#       "total_matches": 2
#     },
#     "filename": "docs/library/tests.mdx"
#   },
#   {
#     "title": "All Descriptors",
#     "description": "Reference page for all row-level text and LLM evals.",
#     "content": {
#       "matches": [
#         "...view) and check the [LLM **Quickstart**](/quickstart_llm). For a...",
#         "...                   |\n\n## **ML**-based evals\n\nUse pre-tra..."
#       ],
#       "total_matches": 2
#     },
#     "filename": "metrics/all_descriptors.mdx"
#   },
#   {
#     "title": "Overview",
#     "description": "Running evals on the platform.",
#     "content": {
#       "matches": [
#         "...**Next step:** check the **Quickstart** for [**ML**](/quickstart_ml)...",
#         "...heck the **Quickstart** for [**ML**](/quickstart_ml) or [LLM..."
#       ],
#       "total_matches": 2
#     },
#     "filename": "docs/platform/evals_overview.mdx"
#   }
# ]</pre>
#             </div>
#
#             </details>
#             <details>
#             <summary>Function call: <tt>search({"query":"Metric cookbook"})</tt></summary>
#             <div>
#                 <b>Call</b>
#                 <pre>{"query":"Metric cookbook"}</pre>
#             </div>
#             <div>
#                 <b>Output</b>
#                 <pre>[
#   {
#     "title": "Custom Metric",
#     "description": "How to create a custom dataset or column-level Metric.",
#     "content": {
#       "matches": [
#         "...u can build fully custom **Metrics**/Tests to handle any colu...",
#         "...s you implement business **metrics**, weighted scores, etc.\n\n...",
#         "... do not require creating **Metrics** from scratch:\n\n  * Add a..."
#       ],
#       "total_matches": 17
#     },
#     "filename": "metrics/customize_metric.mdx"
#   },
#   {
#     "title": "Metric generators",
#     "description": "How to generate multiple metrics at once.",
#     "content": {
#       "matches": [
#         "...le column-level Tests or **Metrics**. To simplify this, you c...",
#         "...mplify this, you can use **metric** generator helper functio...",
#         "...rt Report\nfrom evidently.**metrics** import *\nfrom evidently...."
#       ],
#       "total_matches": 9
#     },
#     "filename": "docs/library/metric_generator.mdx"
#   },
#   {
#     "title": "Tutorials and guides",
#     "description": "End-to-end code examples.",
#     "content": {
#       "matches": [
#         "...different RAG evaluation **metrics**.\n  &lt;/Card&gt;\n  &lt;Card title...",
#         "... &lt;Card title=\"Descriptor **cookbook**\" icon=\"book\" href=\"https...",
#         "...ently/blob/main/examples/**cookbook**/descriptors.ipynb\"&gt;\n    ..."
#       ],
#       "total_matches": 11
#     },
#     "filename": "examples/introduction.mdx"
#   },
#   {
#     "title": "All Metrics",
#     "description": "Reference page for all dataset-level evals.",
#     "content": {
#       "matches": [
#         "... code example, see this [**Metric** **cookbook**](https://github...",
#         "...xample, see this [**Metric** **cookbook**](https://github.com/evid...",
#         "...ently/blob/main/examples/**cookbook**/**metrics**.ipynb).\n&lt;/Info&gt;\n..."
#       ],
#       "total_matches": 145
#     },
#     "filename": "metrics/all_metrics.mdx"
#   },
#   {
#     "title": "Prompt optimization",
#     "description": "[NEW] Automated prompt optimization.",
#     "content": {
#       "matches": [
#         "...ently/blob/main/examples/**cookbook**/prompt_optimization_code...",
#         "...ently/blob/main/examples/**cookbook**/prompt_optimization_book...",
#         "...ently/blob/main/examples/**cookbook**/prompt_optimization_twee..."
#       ],
#       "total_matches": 3
#     },
#     "filename": "docs/library/prompt_optimization.mdx"
#   }
# ]</pre>
#             </div>
#
#             </details>
# -> Response received
#             <details>
#             <summary>Function call: <tt>get_file({"filename":"quickstart_ml.mdx"})</tt></summary>
#             <div>
#                 <b>Call</b>
#                 <pre>{"filename":"quickstart_ml.mdx"}</pre>
#             </div>
#             <div>
#                 <b>Output</b>
#                 <pre>"import CloudSignup from '/snippets/cloud_signup.mdx';\nimport CreateProject from '/snippets/create_project.mdx';\n\n&lt;Info&gt;\n  Need help? Ask on [Discord](https://discord.com/invite/xZjKRaNp8b).\n&lt;/Info&gt;\n\nEvidently helps you run tests and evaluations for your production ML systems. This includes:\n- evaluating prediction quality (e.g. classification or regression accuracy)\n- input data quality (e.g. missing values, out-of-range features)\n- data and prediction drift.\n\nEvaluating distribution shifts ([data drift](https://www.evidentlyai.com/ml-in-production/data-drift)) in ML inputs and predictions is a typical use case that helps you detect shifts in the model quality and environment even without ground truth labels. \n\nIn this Quickstart, you'll run a simple data drift report in Python and view the results in Evidently Cloud. If you want to stay fully local, you can also do that - just skip a couple steps.\n\n## 1. Set up your environment\n\nFor a fully local flow, skip steps 1.1 and 1.3.\n\n### 1.1. Set up Evidently Cloud\n\n&lt;CloudSignup /&gt;\n\n### 1.2. Installation and imports\n\nInstall the Evidently Python library:\n\n```python\n!pip install evidently\n```\n\nComponents to run the evals:\n\n```python\nimport pandas as pd\nfrom sklearn import datasets\n    \nfrom evidently import Dataset\nfrom evidently import DataDefinition\nfrom evidently import Report\nfrom evidently.presets import DataDriftPreset, DataSummaryPreset \n```\n\nComponents to connect with Evidently Cloud:\n\n```python\nfrom evidently.ui.workspace import CloudWorkspace\n```\n\n### 1.3. Create a Project\n\n&lt;CreateProject /&gt;\n\n\n## 2. Prepare a toy dataset\n\nLet's import a toy dataset with tabular data:\n\n```python\nadult_data = datasets.fetch_openml(name=\"adult\", version=2, as_frame=\"auto\")\nadult = adult_data.frame\n```\n\n&lt;Accordion title=\"Have trouble downloading the data?\" defaultOpen={false}&gt;\n  If OpenML is not available, you can download the same dataset from here:\n\n  ```python\n  url = \"https://github.com/evidentlyai/evidently/blob/main/test_data/adults.parquet?raw=true\"\n  adult = pd.read_parquet(url, engine='pyarrow')\n  ```\n&lt;/Accordion&gt;\n\nLet's split the data into two and introduce some artificial drift for demo purposes. `Prod` data will include people with education levels unseen in the reference dataset:\n\n```python\nadult_ref = adult[~adult.education.isin([\"Some-college\", \"HS-grad\", \"Bachelors\"])]\nadult_prod = adult[adult.education.isin([\"Some-college\", \"HS-grad\", \"Bachelors\"])]\n```\n\nMap the column types:\n\n```python\nschema = DataDefinition(\n    numerical_columns=[\"education-num\", \"age\", \"capital-gain\", \"hours-per-week\", \"capital-loss\", \"fnlwgt\"],\n    categorical_columns=[\"education\", \"occupation\", \"native-country\", \"workclass\", \"marital-status\", \"relationship\", \"race\", \"sex\", \"class\"],\n    )\n```\n\nCreate Evidently Datasets to work with:\n\n```python\neval_data_1 = Dataset.from_pandas(\n    pd.DataFrame(adult_prod),\n    data_definition=schema\n)\n```\n\n```python\neval_data_2 = Dataset.from_pandas(\n    pd.DataFrame(adult_ref),\n    data_definition=schema\n)\n```\n\n`Eval_data_2` will be our reference dataset we'll compare against. \n\n## 3. Get a Report\n\nLet's generate a Data Drift preset that will check for statistical distribution changes between all columns in the dataset. \n\n```python\nreport = Report([\n    DataDriftPreset() \n])\n\nmy_eval = report.run(eval_data_1, eval_data_2)\n```\n\n&lt;Info&gt;\nYou can [customize drift parameters](/metrics/customize_data_drift) by choosing different methods and thresholds. In our case we proceed as is so [default tests](/metrics/explainer_drift) selected by Evidently will apply. \n&lt;/Info&gt;\n\n## 4. Explore the results\n\n**Local preview**. In a Python environment like Jupyter notebook or Colab, run:\n\n```python\nmy_eval\n```\n\nThis will render the Report direc ...
#             </div>
#
#             </details>
#             <details>
#             <summary>Function call: <tt>get_file({"filename":"metrics/all_metrics.mdx"})</tt></summary>
#             <div>
#                 <b>Call</b>
#                 <pre>{"filename":"metrics/all_metrics.mdx"}</pre>
#             </div>
#             <div>
#                 <b>Output</b>
#                 <pre>"&lt;Info&gt;\n  For an intro, read [Core Concepts](/docs/library/overview) and check quickstarts for [LLMs](docs/quickstart_llm) or [ML](docs/quickstart_ml). For a reference code example, see this [Metric cookbook](https://github.com/evidentlyai/evidently/blob/main/examples/cookbook/metrics.ipynb).\n&lt;/Info&gt;\n\n&lt;Accordion title=\"How to read the tables\" defaultOpen={false}&gt;\n  * **Metric**: the name of Metric or Preset you can pass to `Report`.\n\n  * **Description:** what it does. Complex Metrics link to explainer pages.\n\n  * **Parameters:** available options. You can also add conditional `tests` to any Metric with standard operators like `eq` (equal), `gt` (greater than), etc. [How Tests work](/docs/library/tests).\n\n  * **Test defaults** are conditions that apply when you invoke Tests but do not set a pass/fail condition yourself.\n\n    * **With reference**: if you provide a reference dataset during the Report `run`, the conditions are set relative to reference.\n\n    * **No reference**: if you do not provide a reference, Tests will use fixed heuristics (like expect no missing values).\n&lt;/Accordion&gt;\n\n## Text Evals\n\nSummarizes results of text or LLM evals. To score individual inputs, first use [descriptors](/metrics/all_descriptors).\n\n&lt;Info&gt;\n  [Data definition](/docs/library/data_definition). You may need to map text columns.\n&lt;/Info&gt;\n\n| Metric          | Description                                                                                                                                                                                                                                                                                             | Parameters                                 | Test Defaults                          |\n| --------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------ | -------------------------------------- |\n| **TextEvals()** | &lt;ul&gt;&lt;li&gt;Large Preset.&lt;/li&gt;&lt;li&gt;Shows `ValueStats` for all descriptors.&lt;/li&gt;&lt;li&gt;You must specify descriptors ([see how](/docs/library/descriptors) and [all descriptors](/metrics/all_descriptors)).&lt;/li&gt;&lt;li&gt;Metric result: for all Metrics.&lt;/li&gt;&lt;li&gt;[Preset page](/metrics/preset_text_evals).&lt;/li&gt;&lt;/ul&gt; | **Optional**:  &lt;ul&gt;&lt;li&gt;`columns`&lt;/li&gt;&lt;/ul&gt; | As in Metrics included in `ValueStats` |\n\n## Columns\n\nUse to aggregate descriptor results or check data quality on column level.\n\n&lt;Info&gt;\n  You may need to map column types using [Data definition](/docs/library/data_definition).\n&lt;/Info&gt;\n\n### Value stats\n\nDescriptive statistics.\n\n| Metric                                                                                                         | Description                                                                                                                                                                                                                                 | Parameters                                                                                                                                        | Test Defaults                                                                                                                        |\n| -------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ---------- ...
# -> Response received
#             <div>
#                 <div><b>Assistant:</b></div>
#                 <div><p>Based on the retrieved documents, here’s a consolidated answer regarding how to use the platform to monitor your machine learning models, including relevant code snippets for monitoring specifically:</p>
# <h3>Overview</h3>
# <p>You can monitor machine learning models using the platform by evaluating metrics such as prediction quality, input data quality, and data drift. Here's how to set up and run evaluations along with necessary code snippets.</p>
# <h3>Steps to Monitor Models</h3>
# <ol>
# <li><p><strong>Set Up the Environment:</strong>
# First, ensure you have the platform's Python library installed. Execute the following command:</p>
# <pre><code class="language-python">!pip install evidently
# </code></pre>
# </li>
# <li><p><strong>Import Necessary Libraries:</strong>
# Next, import the required packages:</p>
# <pre><code class="language-python">import pandas as pd
# from sklearn import datasets
# from evidently import Dataset
# from evidently import Report
# from evidently.presets import DataDriftPreset, DataSummaryPreset
# </code></pre>
# </li>
# <li><p><strong>Load Your Dataset:</strong>
# For demonstration, load a sample dataset:</p>
# <pre><code class="language-python">adult_data = datasets.fetch_openml(name=&quot;adult&quot;, version=2, as_frame=&quot;auto&quot;)
# adult = adult_data.frame
# </code></pre>
# </li>
# <li><p><strong>Define Data Schema:</strong>
# Set the schema for the dataset:</p>
# <pre><code class="language-python">schema = DataDefinition(
#     numerical_columns=[&quot;education-num&quot;, &quot;age&quot;, &quot;capital-gain&quot;, &quot;hours-per-week&quot;, &quot;capital-loss&quot;, &quot;fnlwgt&quot;],
#     categorical_columns=[&quot;education&quot;, &quot;occupation&quot;, &quot;native-country&quot;, &quot;workclass&quot;, &quot;marital-status&quot;, &quot;relationship&quot;, &quot;race&quot;, &quot;sex&quot;, &quot;class&quot;],
# )
# </code></pre>
# </li>
# <li><p><strong>Create Datasets for Evaluation:</strong>
# Create datasets for the reference (old) and current (production) data:</p>
# <pre><code class="language-python">eval_data_1 = Dataset.from_pandas(pd.DataFrame(adult_prod), data_definition=schema)
# eval_data_2 = Dataset.from_pandas(pd.DataFrame(adult_ref), data_definition=schema)
# </code></pre>
# </li>
# <li><p><strong>Generate a Report for Data Drift:</strong>
# To evaluate data drift, run:</p>
# <pre><code class="language-python">report = Report([DataDriftPreset()])
# my_eval = report.run(eval_data_1, eval_data_2)
# </code></pre>
# </li>
# <li><p><strong>Explore the Report:</strong>
# You can preview the results in a Jupyter notebook by running:</p>
# <pre><code class="language-python">my_eval
# </code></pre>
# <p>Alternatively, if you wish to save the report:</p>
# <pre><code class="language-python">my_eval.save_html(&quot;my_report.html&quot;)
# </code></pre>
# </li>
# <li><p><strong>Continuous Monitoring:</strong>
# If needed, you can set up continuous evaluation:</p>
# <pre><code class="language-python">ws.add_run(project.id, my_eval, include_data=False)
# </code></pre>
# </li>
# </ol>
# <h3>Additional Metrics</h3>
# <p>You can also utilize different presets and metrics for assessing model performance, such as <code>DataSummaryPreset()</code> to evaluate overall data quality and health.</p>
# <h3>Summary</h3>
# <p>By following these steps, you can efficiently monitor machine learning models, track performance over time, and respond to any significant changes indicated by the metrics. For comprehensive usage, refer to the various tutorials and guides provided in the platform documentation.</p>
# </div>
#             </div>
